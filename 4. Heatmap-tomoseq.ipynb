# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\bbara\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
input_file = 'normalized_gene_expression.xlsx'   
normalized_df = pd.read_excel(input_file)

# %%
print(normalized_df)
# Out:
#       Gene             13             14             15             16  \
# 0   Adgre5       0.020369       0.003845       0.002671       0.000000
# 1   Adgre1       0.020369       0.003845       0.002671       0.000000
# 2   Adgrl1       0.020369   89303.420751   88786.357464   82133.169175
# 3   Celsr1       0.020369   60954.116488   69079.769679   66267.403368
# 4   Adgrg7       0.020369       0.003845       0.002671       0.001790
# 5   Celsr3       0.020369       0.003845       0.002671       0.001790
# 6   Adgrf4       0.020369       0.003845       0.002671       0.001790
# 7   Adgra1       0.020369       0.003845       0.002671       0.000000
# 8     Hprt       0.020369   60954.116488   80176.751720   89586.764764
# 9   Adgrl2       0.000000  133080.235521  111477.997638  105025.399021
# 10  Adgrb2       0.020369       0.003845       0.002671   17900.897728
# 11  Adgra3  203720.984439  115395.095911   88786.357464   94043.155695
# ...

# %%
normalized_df = normalized_df.sort_values(by="Gene")
mm = normalized_df.set_index("Gene")
plt.figure(figsize=(11,11) )
sns.heatmap(mm)
#plt.savefig('log_transformed_selected_normalized.png')
